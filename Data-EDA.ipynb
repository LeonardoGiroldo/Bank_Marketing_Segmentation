# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
creditcard_df_cleaned = pd.read_csv('Data-Cleaned.csv')
creditcard_df_cleaned
# Out:
#       Unnamed: 0      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0              0    40.900749           0.818182      95.40              0.00
# 1              1  3202.467416           0.909091       0.00              0.00
# 2              2  2495.148862           1.000000     773.17            773.17
# 3              3  1666.670542           0.636364    1499.00           1499.00
# 4              4   817.714335           1.000000      16.00             16.00
# ...          ...          ...                ...        ...               ...
# 8944        8945    28.493517           1.000000     291.12              0.00
# 8945        8946    19.183215           1.000000     300.00              0.00
# 8946        8947    23.398673           0.833333     144.40              0.00
# 8947        8948    13.457564           0.833333       0.00              0.00
# 8948        8949   372.708075           0.666667    1093.25           1093.25
#
# ...

# %%
creditcard_df_cleaned.drop(['Unnamed: 0'], axis = 'columns', inplace = True)

# %%
creditcard_df_cleaned.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
n = len(creditcard_df_cleaned.columns)
n
# Out:
# 17

# %%
plt.figure(figsize=(10,50))
for i in range(n):
  plt.subplot(17, 1, i+1)
  sns.distplot(creditcard_df_cleaned[creditcard_df_cleaned.columns[i]])
  plt.title(creditcard_df_cleaned.columns[i])

plt.tight_layout()
# Out:
# C:\Users\Leonardo\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
correlations = creditcard_df_cleaned.corr()

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(correlations, annot = True)
